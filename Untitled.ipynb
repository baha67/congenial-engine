# %%
Baha is a Data Astronaut
# Out:
#   File "<ipython-input-1-f72db516a725>", line 1
#     Baha is a Data Astronaut
#                  ^
# SyntaxError: invalid syntax

# %%
# This is a heading
* This a bullet
This is some text
# Out:
#   File "<ipython-input-2-64674bf2500d>", line 2
#     * This a bullet
#            ^
# SyntaxError: invalid syntax

# %%
print("Waterbears are astronauts")
# Out:
# Waterbears are astronauts
